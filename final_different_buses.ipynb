# %%
import pandas as pd
df = pd.read_csv('final_different_buses.csv')
df
# Out:
#     serviced ratio  year  month  day  \
# 0         0.942675  2023      2   25
# 1         0.993631  2023      2   25
# 2         1.000000  2023      2   25
# 3         0.812785  2023      2   27
# 4         0.972603  2023      2   27
# 5         1.000000  2023      2   27
# 6         0.929936  2023      2   25
# 7         0.904459  2023      2   25
# 8         0.980892  2023      2   25
# 9         0.993631  2023      2   25
# 10        1.000000  2023      2   25
# 11        1.000000  2023      2   25
# 12        0.748858  2023      2   27
# 13        0.753425  2023      2   27
# 14        0.968037  2023      2   27
# 15        0.963470  2023      2   27
# 16        0.990868  2023      2   27
# 17        1.000000  2023      2   27
# 18        0.947761  2023      2   26
# 19        1.000000  2023      2   26
# 20        1.000000  2023      2   26
# 21        0.872928  2023      2   28
# 22        0.955801  2023      2   28
# 23        1.000000  2023      2   28
# 24        0.925373  2023      2   26
# 25        0.925373  2023      2   26
# 26        1.000000  2023      2   26
# 27        1.000000  2023      2   26
# 28        1.000000  2023      2   26
# 29        1.000000  2023      2   26
# 30        0.856354  2023      2   28
# 31        0.823204  2023      2   28
# 32        0.939227  2023      2   28
# 33        0.944751  2023      2   28
# 34        0.994475  2023      2   28
# 35        0.994475  2023      2   28
# 36        0.585987  2023      2   25
# 37        0.456621  2023      2   27
# 38        0.566879  2023      2   25
# 39        0.541401  2023      2   25
# 40        0.420091  2023      2   27
# 41        0.438356  2023      2   27
# 42        0.701493  2023      2   26
# 43        0.530387  2023      2   28
# 44        0.626866  2023      2   26
# 45        0.671642  2023      2   26
# 46        0.469613  2023      2   28
# 47        0.508287  2023      2   28
#
#     Average Passenger Wait Time at the origin station  \
# 0                                          631.006757
# 1                                          588.666667
# 2                                          572.866242
# 3                                          653.275281
# 4                                          663.089202
# 5                                          631.324201
# 6                                          629.479452
# 7                                          617.359155
# 8                                          580.441558
# 9                                          577.666667
# 10                                         573.668790
# 11                                         572.866242
# 12                                         685.731707
# 13                                         695.593939
# 14                                         643.882075
# 15                                         662.417062
# 16                                         628.705069
# 17                                         634.287671
# 18                                         645.559055
# 19                                         576.992537
# 20                                         562.216418
# 21                                         683.930380
# 22                                         634.786127
# 23                                         615.088398
# 24                                         623.153226
# 25                                         608.677419
# 26                                         545.298507
# 27                                         578.820896
# 28                                         552.992537
# 29                                         562.216418
# 30                                         619.690323
# 31                                         643.778523
# 32                                         631.570588
# 33                                         609.947368
# 34                                         610.116667
# 35                                         591.105556
# 36                                         696.380435
# 37                                         644.440000
# 38                                         635.516854
# 39                                         599.988235
# 40                                         672.173913
# 41                                         652.604167
# 42                                         637.882979
# 43                                         653.489583
# 44                                         615.976190
# 45                                         613.388889
# 46                                         663.270588
# 47                                         644.663043
#
#     Average Passenger Wait Time inside the bus  rejected_requests  mode  \
# 0                                   155.722973                  9     2
# 1                                    45.147436                  1     2
# 2                                     6.388535                  0     2
# 3                                   363.668539                 41     2
# 4                                   116.469484                  6     2
# 5                                    34.534247                  0     2
# 6                                   176.328767                 11     2
# 7                                   197.387324                 15     2
# 8                                    44.084416                  3     2
# 9                                    64.564103                  1     2
# 10                                    9.598726                  0     2
# 11                                    6.388535                  0     2
# 12                                  363.542683                 55     2
# 13                                  393.690909                 54     2
# 14                                  130.108491                  7     2
# 15                                  155.502370                  8     2
# 16                                   35.889401                  2     2
# 17                                   43.684932                  0     2
# 18                                  155.645669                  7     2
# 19                                   18.783582                  0     2
# 20                                    0.000000                  0     2
# 21                                  249.449367                 23     2
# 22                                   86.566474                  8     2
# 23                                   46.983425                  0     2
# 24                                  145.927419                 10     2
# 25                                  195.733871                 10     2
# 26                                   12.492537                  0     2
# 27                                   15.507463                  0     2
# 28                                    0.000000                  0     2
# 29                                    0.000000                  0     2
# 30                                  273.729032                 26     2
# 31                                  281.872483                 32     2
# 32                                  135.835294                 11     2
# 33                                  118.105263                 10     2
# 34                                   58.822222                  1     2
# 35                                   54.805556                  1     2
# 36                                  382.815217                 65     2
# 37                                  444.440000                119     2
# 38                                  380.674157                 68     2
# 39                                  430.835294                 72     2
# 40                                  447.097826                127     2
# 41                                  435.500000                123     2
# 42                                  343.180851                 40     2
# 43                                  360.343750                 85     2
# 44                                  405.285714                 50     2
# 45                                  335.655556                 44     2
# 46                                  448.905882                 96     2
# 47                                  404.195652                 89     2
#
#     cost_mode  IMPERFECT_GENERATIVE_MODEL  ...  total_requests  num_buses  \
# 0           1                       False  ...             157          2
# 1           1                       False  ...             157          3
# 2           1                       False  ...             157          4
# 3           1                       False  ...             219          2
# 4           1                       False  ...             219          3
# 5           1                       False  ...             219          4
# 6           1                        True  ...             157          2
# 7           1                        True  ...             157          2
# 8           1                        True  ...             157          3
# 9           1                        True  ...             157          3
# 10          1                        True  ...             157          4
# 11          1                        True  ...             157          4
# 12          1                        True  ...             219          2
# 13          1                        True  ...             219          2
# 14          1                        True  ...             219          3
# 15          1                        True  ...             219          3
# 16          1                        True  ...             219          4
# 17          1                        True  ...             219          4
# 18          1                       False  ...             134          2
# 19          1                       False  ...             134          3
# 20          1                       False  ...             134          4
# 21          1                       False  ...             181          2
# 22          1                       False  ...             181          3
# 23          1                       False  ...             181          4
# 24          1                        True  ...             134          2
# 25          1                        True  ...             134          2
# 26          1                        True  ...             134          3
# 27          1                        True  ...             134          3
# 28          1                        True  ...             134          4
# 29          1                        True  ...             134          4
# 30          1                        True  ...             181          2
# 31          1                        True  ...             181          2
# 32          1                        True  ...             181          3
# 33          1                        True  ...             181          3
# 34          1                        True  ...             181          4
# 35          1                        True  ...             181          4
# 36          1                       False  ...             157          1
# 37          1                       False  ...             219          1
# 38          1                        True  ...             157          1
# 39          1                        True  ...             157          1
# 40          1                        True  ...             219          1
# 41          1                        True  ...             219          1
# 42          1                       False  ...             134          1
# 43          1                       False  ...             181          1
# 44          1                        True  ...             134          1
# 45          1                        True  ...             134          1
# 46          1                        True  ...             181          1
# 47          1                        True  ...             181          1
#
#     K_max  MCTS_depth  N_chains  Timeout  iterations  \
# 0       5           6         6       60         100
# 1       5           6         6       60         100
# 2       5           6         6       60         100
# 3       5           6         6       60         100
# 4       5           6         6       60         100
# 5       5           6         6       60         100
# 6       5           6         6       60         100
# 7       5           6         6       60         100
# 8       5           6         6       60         100
# 9       5           6         6       60         100
# 10      5           6         6       60         100
# 11      5           6         6       60         100
# 12      5           6         6       60         100
# 13      5           6         6       60         100
# 14      5           6         6       60         100
# 15      5           6         6       60         100
# 16      5           6         6       60         100
# 17      5           6         6       60         100
# 18      5           6         6       60         100
# 19      5           6         6       60         100
# 20      5           6         6       60         100
# 21      5           6         6       60         100
# 22      5           6         6       60         100
# 23      5           6         6       60         100
# 24      5           6         6       60         100
# 25      5           6         6       60         100
# 26      5           6         6       60         100
# 27      5           6         6       60         100
# 28      5           6         6       60         100
# 29      5           6         6       60         100
# 30      5           6         6       60         100
# 31      5           6         6       60         100
# 32      5           6         6       60         100
# 33      5           6         6       60         100
# 34      5           6         6       60         100
# 35      5           6         6       60         100
# 36      5           6         6       60         100
# 37      5           6         6       60         100
# 38      5           6         6       60         100
# 39      5           6         6       60         100
# 40      5           6         6       60         100
# 41      5           6         6       60         100
# 42      5           6         6       60         100
# 43      5           6         6       60         100
# 44      5           6         6       60         100
# 45      5           6         6       60         100
# 46      5           6         6       60         100
# 47      5           6         6       60         100
#
#     Max wait time at station  Max wait time inside bus  MCTS_TUNING_PARAM
# 0                        900                       900               1000
# 1                        900                       900               1000
# 2                        900                       900               1000
# 3                        900                       900               1000
# 4                        900                       900               1000
# 5                        900                       900               1000
# 6                        900                       900               1000
# 7                        900                       900               1000
# 8                        900                       900               1000
# 9                        900                       900               1000
# 10                       900                       900               1000
# 11                       900                       900               1000
# 12                       900                       900               1000
# 13                       900                       900               1000
# 14                       900                       900               1000
# 15                       900                       900               1000
# 16                       900                       900               1000
# 17                       900                       900               1000
# 18                       900                       900               1000
# 19                       900                       900               1000
# 20                       900                       900               1000
# 21                       900                       900               1000
# 22                       900                       900               1000
# 23                       900                       900               1000
# 24                       900                       900               1000
# 25                       900                       900               1000
# 26                       900                       900               1000
# 27                       900                       900               1000
# 28                       900                       900               1000
# 29                       900                       900               1000
# 30                       900                       900               1000
# 31                       900                       900               1000
# 32                       900                       900               1000
# 33                       900                       900               1000
# 34                       900                       900               1000
# 35                       900                       900               1000
# 36                       900                       900               1000
# 37                       900                       900               1000
# 38                       900                       900               1000
# 39                       900                       900               1000
# 40                       900                       900               1000
# 41                       900                       900               1000
# 42                       900                       900               1000
# 43                       900                       900               1000
# 44                       900                       900               1000
# 45                       900                       900               1000
# 46                       900                       900               1000
# 47                       900                       900               1000
#
# [48 rows x 21 columns]

# %%
df['combined'] = df.apply(lambda row: f"{row['mode']}_{row['cost_mode']}_{row['IMPERFECT_GENERATIVE_MODEL']}_{row['BETTER_GEN_MODEL']}", axis=1)
df
mapping = {'1_1_False_False': 'greedy',
 '2_1_False_False': 'perfect',
 '2_1_True_True': 'imperfect_ours',
 '2_1_True_False': 'imperfect_baseline',
 }


# Rename the values in the 'combined' column based on the mapping
df['combined'] = df['combined'].map(mapping)
df = df.sort_values(by='combined')
# Display the DataFrame to verify the changes
df
# Out:
#     serviced ratio  year  month  day  \
# 47        0.508287  2023      2   28
# 33        0.944751  2023      2   28
# 30        0.856354  2023      2   28
# 28        1.000000  2023      2   26
# 26        1.000000  2023      2   26
# 24        0.925373  2023      2   26
# 38        0.566879  2023      2   25
# 40        0.420091  2023      2   27
# 14        0.968037  2023      2   27
# 12        0.748858  2023      2   27
# 17        1.000000  2023      2   27
# 35        0.994475  2023      2   28
# 45        0.671642  2023      2   26
# 8         0.980892  2023      2   25
# 6         0.929936  2023      2   25
# 10        1.000000  2023      2   25
# 32        0.939227  2023      2   28
# 31        0.823204  2023      2   28
# 44        0.626866  2023      2   26
# 29        1.000000  2023      2   26
# 27        1.000000  2023      2   26
# 25        0.925373  2023      2   26
# 41        0.438356  2023      2   27
# 11        1.000000  2023      2   25
# 39        0.541401  2023      2   25
# 7         0.904459  2023      2   25
# 34        0.994475  2023      2   28
# 16        0.990868  2023      2   27
# 15        0.963470  2023      2   27
# 13        0.753425  2023      2   27
# 9         0.993631  2023      2   25
# 46        0.469613  2023      2   28
# 37        0.456621  2023      2   27
# 42        0.701493  2023      2   26
# 43        0.530387  2023      2   28
# 36        0.585987  2023      2   25
# 0         0.942675  2023      2   25
# 21        0.872928  2023      2   28
# 20        1.000000  2023      2   26
# 19        1.000000  2023      2   26
# 18        0.947761  2023      2   26
# 5         1.000000  2023      2   27
# 4         0.972603  2023      2   27
# 3         0.812785  2023      2   27
# 2         1.000000  2023      2   25
# 1         0.993631  2023      2   25
# 22        0.955801  2023      2   28
# 23        1.000000  2023      2   28
#
#     Average Passenger Wait Time at the origin station  \
# 47                                         644.663043
# 33                                         609.947368
# 30                                         619.690323
# 28                                         552.992537
# 26                                         545.298507
# 24                                         623.153226
# 38                                         635.516854
# 40                                         672.173913
# 14                                         643.882075
# 12                                         685.731707
# 17                                         634.287671
# 35                                         591.105556
# 45                                         613.388889
# 8                                          580.441558
# 6                                          629.479452
# 10                                         573.668790
# 32                                         631.570588
# 31                                         643.778523
# 44                                         615.976190
# 29                                         562.216418
# 27                                         578.820896
# 25                                         608.677419
# 41                                         652.604167
# 11                                         572.866242
# 39                                         599.988235
# 7                                          617.359155
# 34                                         610.116667
# 16                                         628.705069
# 15                                         662.417062
# 13                                         695.593939
# 9                                          577.666667
# 46                                         663.270588
# 37                                         644.440000
# 42                                         637.882979
# 43                                         653.489583
# 36                                         696.380435
# 0                                          631.006757
# 21                                         683.930380
# 20                                         562.216418
# 19                                         576.992537
# 18                                         645.559055
# 5                                          631.324201
# 4                                          663.089202
# 3                                          653.275281
# 2                                          572.866242
# 1                                          588.666667
# 22                                         634.786127
# 23                                         615.088398
#
#     Average Passenger Wait Time inside the bus  rejected_requests  mode  \
# 47                                  404.195652                 89     2
# 33                                  118.105263                 10     2
# 30                                  273.729032                 26     2
# 28                                    0.000000                  0     2
# 26                                   12.492537                  0     2
# 24                                  145.927419                 10     2
# 38                                  380.674157                 68     2
# 40                                  447.097826                127     2
# 14                                  130.108491                  7     2
# 12                                  363.542683                 55     2
# 17                                   43.684932                  0     2
# 35                                   54.805556                  1     2
# 45                                  335.655556                 44     2
# 8                                    44.084416                  3     2
# 6                                   176.328767                 11     2
# 10                                    9.598726                  0     2
# 32                                  135.835294                 11     2
# 31                                  281.872483                 32     2
# 44                                  405.285714                 50     2
# 29                                    0.000000                  0     2
# 27                                   15.507463                  0     2
# 25                                  195.733871                 10     2
# 41                                  435.500000                123     2
# 11                                    6.388535                  0     2
# 39                                  430.835294                 72     2
# 7                                   197.387324                 15     2
# 34                                   58.822222                  1     2
# 16                                   35.889401                  2     2
# 15                                  155.502370                  8     2
# 13                                  393.690909                 54     2
# 9                                    64.564103                  1     2
# 46                                  448.905882                 96     2
# 37                                  444.440000                119     2
# 42                                  343.180851                 40     2
# 43                                  360.343750                 85     2
# 36                                  382.815217                 65     2
# 0                                   155.722973                  9     2
# 21                                  249.449367                 23     2
# 20                                    0.000000                  0     2
# 19                                   18.783582                  0     2
# 18                                  155.645669                  7     2
# 5                                    34.534247                  0     2
# 4                                   116.469484                  6     2
# 3                                   363.668539                 41     2
# 2                                     6.388535                  0     2
# 1                                    45.147436                  1     2
# 22                                   86.566474                  8     2
# 23                                   46.983425                  0     2
#
#     cost_mode  IMPERFECT_GENERATIVE_MODEL  ...  num_buses  K_max  MCTS_depth  \
# 47          1                        True  ...          1      5           6
# 33          1                        True  ...          3      5           6
# 30          1                        True  ...          2      5           6
# 28          1                        True  ...          4      5           6
# 26          1                        True  ...          3      5           6
# 24          1                        True  ...          2      5           6
# 38          1                        True  ...          1      5           6
# 40          1                        True  ...          1      5           6
# 14          1                        True  ...          3      5           6
# 12          1                        True  ...          2      5           6
# 17          1                        True  ...          4      5           6
# 35          1                        True  ...          4      5           6
# 45          1                        True  ...          1      5           6
# 8           1                        True  ...          3      5           6
# 6           1                        True  ...          2      5           6
# 10          1                        True  ...          4      5           6
# 32          1                        True  ...          3      5           6
# 31          1                        True  ...          2      5           6
# 44          1                        True  ...          1      5           6
# 29          1                        True  ...          4      5           6
# 27          1                        True  ...          3      5           6
# 25          1                        True  ...          2      5           6
# 41          1                        True  ...          1      5           6
# 11          1                        True  ...          4      5           6
# 39          1                        True  ...          1      5           6
# 7           1                        True  ...          2      5           6
# 34          1                        True  ...          4      5           6
# 16          1                        True  ...          4      5           6
# 15          1                        True  ...          3      5           6
# 13          1                        True  ...          2      5           6
# 9           1                        True  ...          3      5           6
# 46          1                        True  ...          1      5           6
# 37          1                       False  ...          1      5           6
# 42          1                       False  ...          1      5           6
# 43          1                       False  ...          1      5           6
# 36          1                       False  ...          1      5           6
# 0           1                       False  ...          2      5           6
# 21          1                       False  ...          2      5           6
# 20          1                       False  ...          4      5           6
# 19          1                       False  ...          3      5           6
# 18          1                       False  ...          2      5           6
# 5           1                       False  ...          4      5           6
# 4           1                       False  ...          3      5           6
# 3           1                       False  ...          2      5           6
# 2           1                       False  ...          4      5           6
# 1           1                       False  ...          3      5           6
# 22          1                       False  ...          3      5           6
# 23          1                       False  ...          4      5           6
#
#     N_chains  Timeout  iterations  Max wait time at station  \
# 47         6       60         100                       900
# 33         6       60         100                       900
# 30         6       60         100                       900
# 28         6       60         100                       900
# 26         6       60         100                       900
# 24         6       60         100                       900
# 38         6       60         100                       900
# 40         6       60         100                       900
# 14         6       60         100                       900
# 12         6       60         100                       900
# 17         6       60         100                       900
# 35         6       60         100                       900
# 45         6       60         100                       900
# 8          6       60         100                       900
# 6          6       60         100                       900
# 10         6       60         100                       900
# 32         6       60         100                       900
# 31         6       60         100                       900
# 44         6       60         100                       900
# 29         6       60         100                       900
# 27         6       60         100                       900
# 25         6       60         100                       900
# 41         6       60         100                       900
# 11         6       60         100                       900
# 39         6       60         100                       900
# 7          6       60         100                       900
# 34         6       60         100                       900
# 16         6       60         100                       900
# 15         6       60         100                       900
# 13         6       60         100                       900
# 9          6       60         100                       900
# 46         6       60         100                       900
# 37         6       60         100                       900
# 42         6       60         100                       900
# 43         6       60         100                       900
# 36         6       60         100                       900
# 0          6       60         100                       900
# 21         6       60         100                       900
# 20         6       60         100                       900
# 19         6       60         100                       900
# 18         6       60         100                       900
# 5          6       60         100                       900
# 4          6       60         100                       900
# 3          6       60         100                       900
# 2          6       60         100                       900
# 1          6       60         100                       900
# 22         6       60         100                       900
# 23         6       60         100                       900
#
#     Max wait time inside bus  MCTS_TUNING_PARAM            combined
# 47                       900               1000  imperfect_baseline
# 33                       900               1000  imperfect_baseline
# 30                       900               1000  imperfect_baseline
# 28                       900               1000  imperfect_baseline
# 26                       900               1000  imperfect_baseline
# 24                       900               1000  imperfect_baseline
# 38                       900               1000  imperfect_baseline
# 40                       900               1000  imperfect_baseline
# 14                       900               1000  imperfect_baseline
# 12                       900               1000  imperfect_baseline
# 17                       900               1000  imperfect_baseline
# 35                       900               1000  imperfect_baseline
# 45                       900               1000  imperfect_baseline
# 8                        900               1000  imperfect_baseline
# 6                        900               1000  imperfect_baseline
# 10                       900               1000  imperfect_baseline
# 32                       900               1000      imperfect_ours
# 31                       900               1000      imperfect_ours
# 44                       900               1000      imperfect_ours
# 29                       900               1000      imperfect_ours
# 27                       900               1000      imperfect_ours
# 25                       900               1000      imperfect_ours
# 41                       900               1000      imperfect_ours
# 11                       900               1000      imperfect_ours
# 39                       900               1000      imperfect_ours
# 7                        900               1000      imperfect_ours
# 34                       900               1000      imperfect_ours
# 16                       900               1000      imperfect_ours
# 15                       900               1000      imperfect_ours
# 13                       900               1000      imperfect_ours
# 9                        900               1000      imperfect_ours
# 46                       900               1000      imperfect_ours
# 37                       900               1000             perfect
# 42                       900               1000             perfect
# 43                       900               1000             perfect
# 36                       900               1000             perfect
# 0                        900               1000             perfect
# 21                       900               1000             perfect
# 20                       900               1000             perfect
# 19                       900               1000             perfect
# 18                       900               1000             perfect
# 5                        900               1000             perfect
# 4                        900               1000             perfect
# 3                        900               1000             perfect
# 2                        900               1000             perfect
# 1                        900               1000             perfect
# 22                       900               1000             perfect
# 23                       900               1000             perfect
#
# [48 rows x 22 columns]

# %%
import pandas as pd
import numpy as np

column = 'num_buses'

grouped_df = df.groupby([column, 'combined']).median().reset_index()
pivot_df = grouped_df.pivot(index=column, columns='combined', values='serviced ratio')
pivot_df['baseline_improvement'] = ((pivot_df['imperfect_ours'] / pivot_df['imperfect_baseline']) - 1)

o = pivot_df['imperfect_ours']
t = pivot_df['imperfect_baseline']
p = pivot_df['perfect']
pivot_df['theoretical maxiumum'] = (o-t)/(p-t) 
pivot_df['theoretical maxiumum'] = pivot_df['theoretical maxiumum'].apply(lambda x: np.nan if x < 0 else x)
pivot_df['theoretical maxiumum'] = pivot_df['theoretical maxiumum'].apply(lambda x: np.nan if x > 1 else x)

final_table = pivot_df[['imperfect_baseline', 'imperfect_ours', 'perfect', 'baseline_improvement', 'theoretical maxiumum']]

# Function to format floats to 4 significant figures
def format_float(x):
    return f"{100*x:.4g}" if isinstance(x, (float, np.floating)) else x

# Apply the formatting function to the entire DataFrame
final_table = final_table.applymap(format_float)

# Convert to LaTeX table
latex_table = final_table.to_latex(index=False, escape=False)

# Save the LaTeX table to a file
with open('table.tex', 'a') as f:
    f.write(latex_table)

final_table
# Out:
# combined  imperfect_baseline imperfect_ours perfect baseline_improvement  \
# num_buses
# 1                      53.76          50.55   55.82               -5.967
# 2                      89.09          86.38   90.78               -3.034
# 3                      97.45          97.86   98.31               0.4193
# 4                        100          99.72     100              -0.2762
#
# combined  theoretical maxiumum
# num_buses
# 1                          nan
# 2                          nan
# 3                        47.23
# 4                          nan

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame and it has columns 'combined', 'num_buses', and 'serviced ratio'

# Set the font size
plt.rcParams.update({'font.size': 12})

# Calculate figure size
a4_length_mm = 297
half_a4_length_mm = a4_length_mm / 2
half_a4_length_inches = half_a4_length_mm / 25.4  # Convert mm to inches
figure_width = half_a4_length_inches * 1.5  # Adjust width to maintain aspect ratio

# Create a boxplot with the new figure size
plt.figure(figsize=(figure_width, half_a4_length_inches))
sns.boxplot(x='num_buses', y='serviced ratio', hue='combined', data=df, palette='husl')

# Set labels and title
plt.xlabel('Number of Buses')
plt.ylabel('Serviced Ratio')
# plt.title('Serviced Ratio by Combined and Number of Buses')

# Rotate x-axis labels for better readability
# plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()

# Save the plot with DPI 300
plt.savefig('/home/igorsadalski/Desktop/igor_master_theis/final_results/main_different_buses.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()
